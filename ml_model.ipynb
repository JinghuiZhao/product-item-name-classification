# %%
import numpy as np 
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('whole_df.csv')

# %%
# Here I downsampled the data to have balanced classes
from sklearn.utils import shuffle

shuffled = df
clothing = shuffled[shuffled['type'] == 'clothing'].sample(n=9000)
shoes = pd.read_csv('shoes.csv', names=['name', 'type']).sample(n=9000)
beauty = shuffled[shuffled['type'] == 'beauty'].sample(n=9000)
accessories = shuffled[shuffled['type'] == 'accessories']
watches = pd.read_csv('watches.csv', names=['name', 'type']).sample(n=9000)
#pet = shuffled[shuffled['type'] == 'pet supplies'].sample(n=5000)
tools = shuffled[shuffled['type'] == 'tools'].sample(n=9000)
houseware = shuffled[shuffled['type'] == 'houseware'].sample(n=9000)

concated = pd.concat([clothing, shoes, accessories, beauty,
                      watches, tools, houseware], ignore_index=True)
# Shuffle the dataset
concated = shuffle(concated)
concated = concated[['name', 'type']].apply(lambda x: x.astype(str).str.lower())

# %%
concated.type.value_counts()
# Out:
# beauty         9000
# houseware      9000
# watches        9000
# clothing       9000
# tools          9000
# shoes          9000
# accessories    8120
# Name: type, dtype: int64

# %%
concated.isna().sum()
# Out:
# name    0
# type    0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(sublinear_tf=True, 
                        min_df=5, norm='l2', 
                        ngram_range=(1, 2), stop_words='english')
features = tfidf.fit_transform(concated[:40000].name).toarray()
features.shape
# Out:
# (40000, 13940)

# %%
labels = concated[:40000].type

# %%
X = features
y = labels

# %%
X.shape
# Out:
# (40000, 13940)

# %%
#Dimenionality reduction. Only using the 100 best features per category
from sklearn.decomposition import PCA
pca = PCA(n_components= 100,random_state=3)
X = pca.fit_transform(X)
X.shape
# Out:
# (40000, 100)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.model_selection import cross_val_score
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.model_selection import cross_val_score
from xgboost import XGBClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.multiclass import OneVsRestClassifier

'''Metrics/Evaluation'''
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_curve, auc, confusion_matrix


models = [RandomForestClassifier(n_estimators=200, random_state=0),
              XGBClassifier(),
              LogisticRegression(random_state=0),
              MultinomialNB(),
              KNeighborsClassifier(),
              LinearSVC()]
CV = 3
cv_df = pd.DataFrame(index=range(CV * len(models)))
entries = []
for model in models:
    model_name = model.__class__.__name__
    accuracies = cross_val_score(model, features[:1000], labels[:1000], scoring='accuracy', cv=CV)
    for fold_idx, accuracy in enumerate(accuracies):
        entries.append((model_name, fold_idx, accuracy))
cv_df = pd.DataFrame(entries, columns=['model_name', 'fold_idx', 'accuracy'])

              
sns.boxplot(x='model_name', y='accuracy', data=cv_df)
sns.stripplot(x='model_name', y='accuracy', data=cv_df, 
              size=8, jitter=True, edgecolor="gray", linewidth=2)
plt.show()

# %% [markdown]
# recommend you that don't use Naive Bayes with SVD or other matrix factorization because Naive Bayes based on applying Bayes' theorem with strong (naive) independence assumptions between the features. Use other classifier, for example

# %%
# Creating a dict of the models
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.model_selection import cross_val_score
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.model_selection import cross_val_score
from xgboost import XGBClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.multiclass import OneVsRestClassifier

from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_curve, auc, confusion_matrix



model_dict = {'Random Forest': RandomForestClassifier(n_estimators=200, random_state=0),
              'XGBClassifier': XGBClassifier(),
              'LogisticRegression': LogisticRegression(random_state=0),
              'K Nearest Neighbor': KNeighborsClassifier(),
              'linearSVM': LinearSVC()}

# Train test split 
X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    test_size=.2,
                                                    random_state=3)

# Function to get the scores for each model in a df
def model_score_df(model_dict):
    model_name, ac_score_list, p_score_list, r_score_list, f1_score_list = [], [], [], [], []
    for k, v in model_dict.items():
        model_name.append(k)
        v.fit(X_train, y_train)
        y_pred = v.predict(X_test)
        ac_score_list.append(accuracy_score(y_test, y_pred))
        p_score_list.append(precision_score(y_test, y_pred, average='macro'))
        r_score_list.append(recall_score(y_test, y_pred, average='macro'))
        f1_score_list.append(f1_score(y_test, y_pred, average='macro'))
        model_comparison_df = pd.DataFrame(
            [model_name, ac_score_list, p_score_list, r_score_list, f1_score_list]).T
        model_comparison_df.columns = [
            'model_name', 'accuracy_score', 'precision_score', 'recall_score', 'f1_score']
        model_comparison_df = model_comparison_df.sort_values(
            by='f1_score', ascending=False)
    return model_comparison_df


model_score_df(model_dict)
# Out:
#            model_name accuracy_score precision_score recall_score  f1_score
# 0       Random Forest       0.806375        0.805148     0.804082  0.804047
# 1       XGBClassifier        0.77125        0.770777     0.768726   0.76865
# 4           linearSVM           0.77        0.767639     0.768013  0.765656
# 2  LogisticRegression       0.764375        0.765191     0.762002  0.761903
# 3  K Nearest Neighbor       0.751125        0.751922     0.749633  0.750553

# %%
names = pd.read_csv('ecommerce_product_names.csv')
names = names.apply(lambda x: x.astype(str).str.lower())

# %%
X_test = tfidf.fit_transform(names['Product Name']).toarray()
X_test = pca.fit_transform(X_test)

# %%
model = RandomForestClassifier()
model.fit(X, y)
y_pred = model.predict(X_test)

# %%
model2 = LinearSVC()
model2.fit(X, y)
y_pred2 = model2.predict(X_test)

# %%
names['prediction'] = y_pred

# %%
names['prediction_2'] = y_pred2

# %%
names.to_csv('pred_ml.csv', index = None)

# %%
names[80:]
# Out:
#                                             Product Name   prediction  \
# 80     t star uft-tsw-005-bk-br analog watch  - for boys        tools
# 81                                          rialto boots        shoes
# 82                                    kielz ladies boots        shoes
# 83     alfajr wy16b youth digital watch  - for men, boys  accessories
# 84                                 la briza ashley boots  accessories
# 85     tag heuer cau1116.ba0858 formula 1 analog watc...    houseware
# 86          salt n pepper 13-019 femme black boots boots  accessories
# 87                                      shuz touch boots     clothing
# 88                     wrangler skanders fit men's jeans      watches
# 89          salt n pepper 14-664 denny black boots boots        shoes
# 90     costa swiss cs-2001 analog watch  - for boys, men     clothing
# 91                                           crocs boots        shoes
# 92     breitling ab011010/bb08 131s chronomat 44 anal...    houseware
# 93                                lyc white casual boots     clothing
# 94                                myra comfortable boots        shoes
# 95     calibro sw-125 analog-digital watch  - for men...    houseware
# 96                         get glamr designer uggy boots        shoes
# 97                 rochees rw50 analog watch  - for boys      watches
# 98                  salt n pepper 13-516 greta red boots  accessories
# 99          fluid dmf-002-gr01 digital watch  - for boys      watches
# 100    rorlig rr-030 essentials analog watch  - for m...    houseware
# 101                     wrangler regular fit men's jeans      watches
# 102     disney dw100230 digital watch  - for boys, girls        tools
# 103                salt n pepper 13-167 marsha red boots  accessories
# 104       cartier w6701005 analog watch  - for boys, men    houseware
# 105                        bruno manetti cannelita boots     clothing
# 106           stylistry maxis shde6603brwoboot3104 boots        shoes
# 107    lois caron lcs-4032 analog watch  - for boys, men    houseware
# 108             felix y 39 analog watch  - for boys, men    houseware
# 109                                          kielz boots     clothing
# ...                                                  ...          ...
# 12593                       martini women's sheath dress    houseware
# 12594              kashana fashions women's a-line dress        tools
# 12595                          msmb women's a-line dress      watches
# 12596                         kiosha women's shift dress     clothing
# 12597                  my addiction women's a-line dress        tools
# 12598                       indibox women's a-line dress      watches
# 12599            elite collection medium acrylic sticker        shoes
# 12600      wallmantra extra large vinyl stickers sticker        shoes
# 12601                       sindhi footwear women wedges        tools
# 12602            wallmantra large vinyl stickers sticker        shoes
# 12603                     walldesign small vinyl sticker        shoes
# 12604                      999store medium paper sticker        shoes
# 12605           wallmantra medium vinyl stickers sticker        shoes
# 12606                            belle gambe women heels    houseware
# 12607  lord's red women's slingback peeptoes women heels        tools
# 12608     oren empower extra large self adhesive sticker       beauty
# 12609             wallmantra large vinyl sticker sticker        shoes
# 12610       wallmantra extra large vinyl sticker sticker        shoes
# 12611  lord's antique gold women's peeptoe heels wome...    houseware
# 12612                                do bhai women heels  accessories
# 12613  uberlyfe extra large pigmented polyvinyl films...        shoes
# 12614            wallmantra medium vinyl sticker sticker        shoes
# 12615                        fun to see reusable sticker        shoes
# 12616                  sindhi footwear ballerina bellies  accessories
# 12617            wallmantra small vinyl stickers sticker        shoes
# 12618                                 purple women heels  accessories
# 12619                       uberlyfe large vinyl sticker        shoes
# 12620                 we witches comfy hues women wedges    houseware
# 12621                              stylistry women heels    houseware
# 12622                 uberlyfe extra large vinyl sticker        shoes
#
#       prediction_2
# 80       houseware
# 81          beauty
# 82          beauty
# 83       houseware
# 84          beauty
# 85       houseware
# 86          beauty
# 87          beauty
# 88       houseware
# 89          beauty
# 90       houseware
# 91          beauty
# 92       houseware
# 93          beauty
# 94          beauty
# 95       houseware
# 96          beauty
# 97       houseware
# 98          beauty
# 99           shoes
# 100      houseware
# 101      houseware
# 102          shoes
# 103         beauty
# 104      houseware
# 105         beauty
# 106         beauty
# 107      houseware
# 108      houseware
# 109         beauty
# ...            ...
# 12593       beauty
# 12594       beauty
# 12595        tools
# 12596        tools
# 12597       beauty
# 12598        tools
# 12599      watches
# 12600     clothing
# 12601    houseware
# 12602     clothing
# 12603     clothing
# 12604     clothing
# 12605     clothing
# 12606       beauty
# 12607       beauty
# 12608     clothing
# 12609     clothing
# 12610     clothing
# 12611       beauty
# 12612       beauty
# 12613     clothing
# 12614     clothing
# 12615     clothing
# 12616       beauty
# 12617     clothing
# 12618       beauty
# 12619     clothing
# 12620    houseware
# 12621       beauty
# 12622     clothing
#
# [12543 rows x 3 columns]
